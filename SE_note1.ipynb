# %%
#comments

a = 10 #interger
b = 3.14 #float
c = "A" #string
d = "dhiva" #string
e = "Software Engineering" #string
f = 'A' #string
g = 'dhiva' #string
h = 'Software Engineering' #string
i = True #boolean
j = False #boolean
k = [] #list
l = [1,2,3] #list
m = {} #dictionary
n = () #tuple
list1 = ["dhiva", 10, False, 10.1, ['nadhiva', 'fahriani']]

print(list1)

# %%
#print itu buat debugging
print(l)

# %%
nama = "dhiva"
umur = 20

#concatination
print("hello nama aku " + nama + ", umurku " + str(umur))
print("hello nama aku {}, umurku {}".format(nama, umur))

# %%
nama = input()

#concatination
print('hello nama aku ' + nama)
print("hello nama aku {}".format(nama))
print("hello nama aku {}".format("dhiva"))

# %%
a = 10
b = 10

##conditional statement
a == b 
a != b 
a < b
a <= b
a > b
a >= b
True and True
True or False

#operator 
a + b
a - b
a * b
a / b # 10 / 10 = 1.0 -> float division
a // b # 10 // 10 = 1 -> integer division
a ** b # 10^10 = 100
a % b
a ** (1/2) #
math.sqrt(a) #akar variable a, harus import package math dulu
math.sin(a)
math.cos(a)
math.tan(a)
math.sinh(a)
math.cosh(a)
math.tanh(a)
math.log(a)

# %%
a = 2
b = 20

#if else
if a == 10:
  print("a sama dengan 10")
elif a > 10:
  print("a lebih besar dari 10")
else:
  print("a kurang dari 10")
# Out:
# a kurang dari 10
