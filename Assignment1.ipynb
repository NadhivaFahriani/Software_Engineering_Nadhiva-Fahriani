# %%
#time = int(input("Enter the current time: "))

time = 7

if time >= 6 and time <= 12:
  print("please have your breakfast!")
elif time >= 12 and time <= 14:
  print("please have your lunch!")
elif time >= 19 and time <= 21:
  print("please have your dinner!")
else:
  print("you better sleep!!")
# Out:
# please have your breakfast!
